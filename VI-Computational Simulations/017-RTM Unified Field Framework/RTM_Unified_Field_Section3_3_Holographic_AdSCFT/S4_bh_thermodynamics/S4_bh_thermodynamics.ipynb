# %% [markdown]
# # S4_bh_thermodynamics
#
# From: RTM Unified Field Framework - Section 3.3

# %%
# %run S4_bh_thermodynamics.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
