# %% [markdown]
# # S2_threshold_matching
#
# From: RTM Unified Field Framework - Section 3.5

# %%
# %run S2_threshold_matching.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
