# %% [markdown]
# # S5_vascular_tree
#
# From: RTM Unified Field Framework - Section 4

# %%
# %run S5_vascular_tree.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
