# %% [markdown]
# # S1_coleman_weinberg
#
# From: RTM Unified Field Framework - Section 3.1.3

# %%
# %run S1_coleman_weinberg.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
