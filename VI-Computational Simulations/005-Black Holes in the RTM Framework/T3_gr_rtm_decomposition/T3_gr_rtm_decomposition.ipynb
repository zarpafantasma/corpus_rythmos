# %% [markdown]
# # T3_gr_rtm_decomposition
#
# From: Black Holes in the RTM Framework

# %%
# %run T3_gr_rtm_decomposition.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
