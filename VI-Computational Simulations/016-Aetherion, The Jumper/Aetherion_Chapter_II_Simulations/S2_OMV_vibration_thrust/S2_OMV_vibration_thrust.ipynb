# %% [markdown]
# # S2_OMV_vibration_thrust
#
# From: Aetherion, The Jumper - Chapter II

# %%
# %run S2_OMV_vibration_thrust.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
