# %% [markdown]
# # S3_scaling_analysis
#
# From: Aetherion, The Jumper - Chapter I

# %%
# %run S3_scaling_analysis.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
