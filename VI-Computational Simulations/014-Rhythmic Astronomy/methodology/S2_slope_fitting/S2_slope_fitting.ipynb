# %% [markdown]
# # S2_slope_fitting
#
# From: Rhythmic Astronomy: An RTM Slope Law for Galaxy Rotation Curves
#
# **IMPORTANT DISCLAIMER**: This simulation illustrates RTM predictions on synthetic data. Real validation requires comparison with observed galaxy data.

# %%
# %run S2_slope_fitting.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
