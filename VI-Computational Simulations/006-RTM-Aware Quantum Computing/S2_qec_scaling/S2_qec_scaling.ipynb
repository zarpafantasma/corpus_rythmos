# %% [markdown]
# # S2_qec_scaling
#
# From: RTM-Aware Quantum Computing

# %%
# %run S2_qec_scaling.py

# %%
import os
from IPython.display import Image
for f in os.listdir('output'):
    if f.endswith('.png'): display(Image(f'output/{f}'))
