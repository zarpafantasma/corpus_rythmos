# %% [markdown]
# # T2_galaxy_assembly
#
# From: Time–Scale Rescaling in Early Universe Structure Growth
#
# See T2_galaxy_assembly.py for full implementation.

# %%
# Run the main script
# %run T2_galaxy_assembly.py

# %%
# Display outputs
import os
from IPython.display import Image, display
for f in os.listdir('output'):
    if f.endswith('.png'):
        display(Image(f'output/{f}'))
