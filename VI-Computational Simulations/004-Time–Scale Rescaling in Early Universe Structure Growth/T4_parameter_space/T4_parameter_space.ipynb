# %% [markdown]
# # T4_parameter_space
#
# From: Time–Scale Rescaling in Early Universe Structure Growth
#
# See T4_parameter_space.py for full implementation.

# %%
# Run the main script
# %run T4_parameter_space.py

# %%
# Display outputs
import os
from IPython.display import Image, display
for f in os.listdir('output'):
    if f.endswith('.png'):
        display(Image(f'output/{f}'))
