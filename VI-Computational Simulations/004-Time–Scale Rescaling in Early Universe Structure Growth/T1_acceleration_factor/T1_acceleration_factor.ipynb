# %% [markdown]
# # T1_acceleration_factor
#
# From: Time–Scale Rescaling in Early Universe Structure Growth
#
# See T1_acceleration_factor.py for full implementation.

# %%
# Run the main script
# %run T1_acceleration_factor.py

# %%
# Display outputs
import os
from IPython.display import Image, display
for f in os.listdir('output'):
    if f.endswith('.png'):
        display(Image(f'output/{f}'))
