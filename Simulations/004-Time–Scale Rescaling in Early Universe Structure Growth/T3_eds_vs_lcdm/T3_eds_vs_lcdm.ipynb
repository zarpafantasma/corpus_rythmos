# %% [markdown]
# # T3_eds_vs_lcdm
#
# From: Time–Scale Rescaling in Early Universe Structure Growth
#
# See T3_eds_vs_lcdm.py for full implementation.

# %%
# Run the main script
# %run T3_eds_vs_lcdm.py

# %%
# Display outputs
import os
from IPython.display import Image, display
for f in os.listdir('output'):
    if f.endswith('.png'):
        display(Image(f'output/{f}'))
